# %%
import pandas as pd

# %%
horas = list(range(6,2))

df_pendente = pd.read_excel('Setup - Geral - TS F.07 11.xlsm', sheet_name='Pendente')
df_base_ser = pd.read_excel('Setup - Geral - TS F.07 11.xlsm', sheet_name='Base_Custos_Mesa_Ser')
df_res_trocas = pd.read_excel('Setup - Geral - TS F.07 11.xlsm', sheet_name='Resumo_Trocas')
df_dados_pintura = pd.read_excel(
    'Setup - Geral - TS F.07 11.xlsm', 
    sheet_name='Dados',
    header=3,
    usecols="B:E",
    nrows=20
)
# --------------------------------------------------------------------------------------------------
df_dados_pintura = pd.read_excel(
    'Setup - Geral - TS F.07 11.xlsm', 
    sheet_name='Dados',
    header=3,
    usecols="B:E",
    nrows=20
)
df_nec_pintura = pd.read_excel(
    'Setup - Geral - TS F.07 11.xlsm', 
    sheet_name='Dados',
    header=3,
    usecols="G:J",
    nrows=21
)
# --------------------------------------------------------------------------------------------------
df_dados_montagem = pd.read_excel(
    'Setup - Geral - TS F.07 11.xlsm', 
    sheet_name='Dados',
    header=3,
    usecols="L:O",
    nrows=20
)
df_nec_montagem = pd.read_excel(
    'Setup - Geral - TS F.07 11.xlsm', 
    sheet_name='Dados',
    header=3,
    usecols="Q:T",
    nrows=21
)
# --------------------------------------------------------------------------------------------------
df_dados_serigrafia = pd.read_excel(
    'Setup - Geral - TS F.07 11.xlsm', 
    sheet_name='Dados',
    header=3,
    usecols="V:Y",
    nrows=20
)
df_nec_serigrafia = pd.read_excel(
    'Setup - Geral - TS F.07 11.xlsm', 
    sheet_name='Dados',
    header=3,
    usecols="AA:AD",
    nrows=21
)
# --------------------------------------------------------------------------------------------------
df_reg_ser = pd.read_excel(
    'Setup - Geral - TS F.07 11.xlsm', 
    sheet_name='Serigrafia - Reguladores',
    header=17,
    usecols="C:AO",
    nrows=20
)
df_reg_mon = pd.DataFrame()
df_reg_pin = pd.DataFrame()

tab_reg = {
    "serigrafia": df_reg_ser,
    "montagem": df_reg_mon,
    "pintura": df_reg_pin
}

print(df_nec_serigrafia)
# Out:
#      Hora.5  Conferente.2   Telas.5  Troca de cor.5
# 0   Efetivo      2.000000  2.000000        1.000000
# 1        6h      2.970833  2.400000        0.500000
# 2        7h      4.312500  3.066667        0.944444
# 3        8h      2.587500  1.333333        0.388889
# 4        9h      2.300000  1.800000        0.388889
# 5       10h      1.820833  2.333333        0.500000
# 6       11h      0.095833  0.000000        0.055556
# 7       12h      2.012500  1.466667        0.222222
# 8       13h      1.150000  1.000000        0.000000
# 9       14h      1.725000  1.333333        0.388889
# 10      15h      1.629167  2.200000        0.166667
# 11      16h      2.491667  2.066667        0.333333
# 12      17h      2.012500  1.733333        0.166667
# 13      18h      1.916667  1.266667        0.277778
# 14      19h      0.958333  1.133333        0.055556
# 15      20h      0.958333  0.466667        0.111111
# 16      21h      2.204167  1.266667        0.277778
# ...
